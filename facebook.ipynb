# %%
import pandas as pd
import numpy as ny

# %%
df = pd.read_csv('dataset_Facebook.csv' , sep=';')

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df["Type"].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
df_photo = df[df["Type"]=="Photo"]
df_photo
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
df_status = df[df["Type"]=="Status"]
df_status
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# 18             138414  Status         3          12             2          3
# 24             138414  Status         2          12             6         10
# 25             138458  Status         2          12             6          3
# 26             138458  Status         2          12             5         11
# 38             138895  Status         2          12             7          9
# 40             138895  Status         2          12             6         11
# ...

# %%
df_photo.shape
# Out:
# (426, 19)

# %%
df_status.shape
# Out:
# (45, 19)

# %%
df_merge = pd.concat([df_photo,df_status])
df_merge
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 6              139441   Photo         3          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 334            119198  Status         2           5             1          2
# 352            116435  Status         1           5             4          3
# 362            116091  Status         2           5             5          7
# 371            113028  Status         2           4             6          3
# 416            104070  Status         1           3             3         15
#
# ...

# %%
df_merge.shape
# Out:
# (471, 19)

# %%
df_sort = df.sort_values(by="like")
df_sort
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 417            104070  Photo         1           3             3         10
# 100            137020  Photo         1          10             4          9
# 76             137893  Photo         1          11             3          2
# 441             98195  Photo         1           3             5          4
# ..                ...    ...       ...         ...           ...        ...
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
df_sort_comment = df.sort_values(by="comment" , ascending=False)

# %%
df_sort_comment.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 460             92507  Photo         3           2             1         13
# 168            135428  Photo         1           9             3         10
# 288            126141  Photo         1           6             4         12
# 228            131728  Photo         2           7             4          3
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
# 460   0.0                      55520                           665792
# 168   0.0                      41984                            68290
# 288   0.0                      20896                            29062
# 228   0.0                      14824                            21863
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df_transpose = df.transpose()
df_transpose
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df_melt = pd.melt(df)
df_melt
# Out:
#                 variable   value
# 0       Page total likes  139441
# 1       Page total likes  139441
# 2       Page total likes  139441
# 3       Page total likes  139441
# 4       Page total likes  139441
# ...                  ...     ...
# 9495  Total Interactions      84
# 9496  Total Interactions      75
# 9497  Total Interactions     115
# 9498  Total Interactions     136
# 9499  Total Interactions     119
#
# [9500 rows x 2 columns]

# %%
df_melt1=pd.melt(df,id_vars=['Type','Category'],var_name='metrics',value_name='value')
df_melt1
# Out:
#         Type  Category             metrics     value
# 0      Photo         2    Page total likes  139441.0
# 1     Status         2    Page total likes  139441.0
# 2      Photo         3    Page total likes  139441.0
# 3      Photo         2    Page total likes  139441.0
# 4      Photo         2    Page total likes  139441.0
# ...      ...       ...                 ...       ...
# 8495   Photo         3  Total Interactions      84.0
# 8496   Photo         2  Total Interactions      75.0
# 8497   Photo         1  Total Interactions     115.0
# 8498   Photo         3  Total Interactions     136.0
# 8499   Photo         2  Total Interactions     119.0
#
# [8500 rows x 4 columns]

# %%
df_cas = pd.get_dummies(df_melt)
df_cas
# Out:
#       variable_Category  variable_Lifetime Engaged Users  \
# 0                 False                            False
# 1                 False                            False
# 2                 False                            False
# 3                 False                            False
# 4                 False                            False
# ...                 ...                              ...
# 9495              False                            False
# 9496              False                            False
# 9497              False                            False
# 9498              False                            False
# 9499              False                            False
#
#       variable_Lifetime People who have liked your Page and engaged with your post  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# ...
